# %% [markdown]
# # Pandas was initially developed by Wes McKinney in 2008.

# %% [markdown]
# #  It is a Python package that offers various data structures and operations for manipulating  data and . It is mainly popular for importing and analyzing data in much easier way. Pandas is fast and it has high-performance & productivity for users.

# %% [markdown]
# ![Capture1.PNG](attachment:Capture1.PNG)

# %% [markdown]
# ![Capture2.PNG](attachment:Capture2.PNG)

# %% [markdown]
# ![Capture3.PNG](attachment:Capture3.PNG)

# %% [markdown]
# # Pandas Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.)                                      Pandas Series is nothing but a column in an excel sheet.

# %%
import pandas as pd

# %%
l = [2,3,4,6]
ser = pd.Series(l)
ser
# Out:
# 0    2
# 1    3
# 2    4
# 3    6
# dtype: int64

# %%
ser = pd.Series()
ser
# Out:
# <ipython-input-3-fc22660a84e5>:1: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   ser = pd.Series()
# Series([], dtype: float64)

# %%
print(l)
# Out:
# [2, 3, 4, 6]

# %% [markdown]
# # DataFrame

# %% [markdown]
# # Pandas DataFrame is two-dimensional size-mutable data structure with labeled axes (rows and columns)

# %%
l1 =["Amar", "Barsha", "Carlos", "Tanmay", "Misbah"] 
l3 =[23, 25, 22, 11, 29]
ll = list(zip(l1,l3))
print(ll)
print()
d=dict(ll)
print(d)
# Out:
# [('Amar', 23), ('Barsha', 25), ('Carlos', 22), ('Tanmay', 11), ('Misbah', 29)]
#
# {'Amar': 23, 'Barsha': 25, 'Carlos': 22, 'Tanmay': 11, 'Misbah': 29}

# %%
l1 =["Amar", "Barsha", "Carlos", "Tanmay", "Misbah"] 
l2 =["Alpha", "Bravo", "Charlie", "Tango", "Mike"] 
l3 =[23, 25, 22, 11, 29] 
l4 =[69, 54, 73, 70, 74]

l = list(zip(l1,l2,l3,l4))
l
# Out:
# [('Amar', 'Alpha', 23, 69),
#  ('Barsha', 'Bravo', 25, 54),
#  ('Carlos', 'Charlie', 22, 73),
#  ('Tanmay', 'Tango', 11, 70),
#  ('Misbah', 'Mike', 29, 74)]

# %%
l1 =["Amar", "Barsha", "Carlos", "Carlos", "Misbah"] 
l4 =[69, 54, 73, 70, 74]
l=list(zip(l1,l4))
d=dict(l)
d
# Out:
# {'Amar': 69, 'Barsha': 54, 'Carlos': 70, 'Misbah': 74}

# %%
df=pd.DataFrame(ll)
df
# Out:
#         0   1
# 0    Amar  23
# 1  Barsha  25
# 2  Carlos  22
# 3  Tanmay  11
# 4  Misbah  29

# %%
df = pd.DataFrame(l)
df
# Out:
#         0   1
# 0    Amar  69
# 1  Barsha  54
# 2  Carlos  73
# 3  Carlos  70
# 4  Misbah  74

# %%
#assigning  column name
df.columns = ['Name','Code_Name',]
df
# Out:
#      Name  Code_Name
# 0    Amar         69
# 1  Barsha         54
# 2  Carlos         73
# 3  Carlos         70
# 4  Misbah         74

# %%
# Renaming a column name
df=df.rename(columns = {'Code_Name' :'Code'})
df
# Out:
#      Name  Code
# 0    Amar    69
# 1  Barsha    54
# 2  Carlos    73
# 3  Carlos    70
# 4  Misbah    74

# %%
# dictionary
data = {'Height' : [5.5,4.5,6,5,6.5]}
dff = pd.DataFrame(data)
dff
# Out:
#    Height
# 0     5.5
# 1     4.5
# 2     6.0
# 3     5.0
# 4     6.5

# %% [markdown]
# # Adding new column to existing DataFrame in Pandas

# %%
df
# Out:
#      Name  Code
# 0    Amar    69
# 1  Barsha    54
# 2  Carlos    73
# 3  Carlos    70
# 4  Misbah    74

# %%
# df.insert(index,c0lumnName,ovalue)
#data = {'Height' : [5.5,4.5,6,5,6.5]}
df.insert(2,'Height',[5.5,4.5,6,5,6.5])
df
# Out:
#      Name  Code  Height
# 0    Amar    69     5.5
# 1  Barsha    54     4.5
# 2  Carlos    73     6.0
# 3  Carlos    70     5.0
# 4  Misbah    74     6.5

# %%
df
# Out:
#      Name  Code  Height
# 0    Amar    69     5.5
# 1  Barsha    54     4.5
# 2  Carlos    73     6.0
# 3  Carlos    70     5.0
# 4  Misbah    74     6.5

# %% [markdown]
# # Delete rows/columns from DataFrame

# %%
# delete a column
df = df.drop('Code',axis=1)
df
# Out:
#      Name  Height
# 0    Amar     5.5
# 1  Barsha     4.5
# 2  Carlos     6.0
# 3  Carlos     5.0
# 4  Misbah     6.5

# %%
df.head(2)
# Out:
#      Name  Height
# 0    Amar     5.5
# 1  Barsha     4.5

# %%
df.tail(2)
# Out:
#      Name  Height
# 3  Carlos     5.0
# 4  Misbah     6.5

# %%
df.sample(3)
# Out:
#      Name  Height
# 1  Barsha     4.5
# 0    Amar     5.5
# 3  Carlos     5.0

# %%
a=2435
b=2435
print(a==b)
print(a is b)
print(id(a) == id(b))
# Out:
# True
# False
# False

# %%
bin(259)
# Out:
# '0b100000011'
