# %% [markdown]
# # Linear Regression
# Simple linear regression is useful for finding relationship between two continuous variables.
#
# One is predictor or independent variable and other is response or dependent variable.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"areaprice.csv")
df.sample(3)
# Out:
#    area  price
# 5  4400  67000
# 7  3800  59000
# 4  4000  63000

# %%
df.shape#(no_of rows,no_of_column)
# Out:
# (11, 2)

# %% [markdown]
# # Linear reg (single variable)
# ![Capture.PNG](attachment:Capture.PNG)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   area    11 non-null     int64
#  1   price   11 non-null     int64
# dtypes: int64(2)
# memory usage: 304.0 bytes

# %%
plt.scatter(df.area,df.price,marker='+',color='red')
plt.xlabel("Area")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
#reg.fit(df.area,df.price)
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %% [raw]
# price = 3500 * coeff + intercept

# %%
reg.coef_ #coef....?
# Out:
# array([10.49913087])

# %% [markdown]
# # formula for coeff:
# ![coeff.png](attachment:coeff.png)
#
#         here consider (b1 = m 0r slope)

# %%
reg.intercept_    #intercept......?
# Out:
# 20957.784951576854

# %% [markdown]
# # formula![intercept.png](attachment:intercept.png)
#
#          here consider intercept =b0

# %% [markdown]
# # price = area * coef_  + Intercept_

# %% [raw]
# area=3500
# price = 3500 * 10.49913087 + 20957.78495157686
# price = 57704.74299657686

# %%
3500 * 10.49913087 + 20957.78495157686
# Out:
# 57704.74299657686

# %%
reg.predict([[2000]])
# Out:
# array([41956.04668488])

# %%
reg.predict([[2800]])
# Out:
# array([50355.3513782])

# %%
reg.score(df[['area']],df.price)
# Out:
# 0.9855756062210629

# %%
test_df = pd.read_csv(r"area.csv")
test_df.sample(3)
# Out:
#     area
# 11  8970
# 3   3486
# 16  3234

# %%
test_df.shape
# Out:
# (19, 1)

# %%
pred = reg.predict(test_df)

# %%
pred
# Out:
# array([ 55604.91681152,  73453.43928483,  45105.78594487,  57557.75515272,
#         71353.6131115 , 102851.00571145, 121749.44127142,  66104.04767817,
#         45578.24683387, 124647.20139061,  68907.31561957, 115134.98882543,
#         78283.03948349,  57179.78644152,  89874.07996027,  80487.85696548,
#         54911.97417432,  68833.8217035 ,  68833.8217035 ])

# %%
dff = pd.DataFrame({
    "area":test_df.area,
    "pred_Price":pred
})

# %%
#len(dff['area'][:12])

# %%
dff.head(3)
# Out:
#    area    pred_Price
# 0  3300  55604.916812
# 1  5000  73453.439285
# 2  2300  45105.785945

# %%
dff.to_csv("predicted_Area.csv")

# %%
# %matplotlib inline
plt.figure(figsize=(10,15))
plt.xlabel("Area",fontsize=25)
plt.ylabel("Price",fontsize=25)
plt.scatter(df.area,df.price,marker='*',color='red',linewidths=5,label='Actual')
plt.plot(dff.area,dff.pred_Price,color='green',linewidth=1,label='Predicted')

plt.legend()

# %%
# %matplotlib inline
plt.figure(figsize=(5,5))

plt.xlabel("Area",fontsize=25)
plt.ylabel("Price",fontsize=25)
plt.scatter(df.area,df.price,marker='o',color='red',label='Actual')
plt.scatter(dff.area,dff.pred_Price,marker='+',color='black',label='Predicted')

plt.legend()

# %% [markdown]
# # price = area * coef_  + Intercept_ + Error

# %% [markdown]
# # error
# ![error.png](attachment:error.png)

# %%
a=5
b=6
print(a,b)
print("a is",a,"b is ",b)
print(f"a is {a} ,b is {b}")
# Out:
# 5 6
# a is 5 b is  6
# a is 5 ,b is 6

# %%
area=float(input("Enter Area :"))
p = reg.predict([[area]])
print("predicted area is :",p[0])
# Out:
# Enter Area :2000
# predicted area is : 41956.046684877074

# %%
lower=int(input("Enter start limit :"))
upper=int(input("Enter end limit :"))
for area in range(lower,upper+1,100):
    p = reg.predict([[area]])
    print(f"predicted price of area {area}sqft is :{p[0]}")
# Out:
# Enter start limit :1200
# Enter end limit :2000
# predicted price of area 1200sqft is :33556.741991556984
# predicted price of area 1300sqft is :34606.655078222
# predicted price of area 1400sqft is :35656.56816488701
# predicted price of area 1500sqft is :36706.48125155202
# predicted price of area 1600sqft is :37756.39433821703
# predicted price of area 1700sqft is :38806.30742488204
# predicted price of area 1800sqft is :39856.22051154706
# predicted price of area 1900sqft is :40906.133598212065
# predicted price of area 2000sqft is :41956.046684877074

# %%
# now lets make a function of the above function .
def area_price():
    start=int(input("Enter start limit :"))
    last=int(input("Enter last limit :"))
    for area in range(start,last+1,100):
        p = reg.predict([[area]])
        print(f"predicted price of area {area}sqft is :{p[0]}")
#area_price()

# %%
area_price()
# Out:
# Enter start limit :200
# Enter last limit :500
# predicted price of area 200sqft is :23057.611124906878
# predicted price of area 300sqft is :24107.524211571887
# predicted price of area 400sqft is :25157.4372982369
# predicted price of area 500sqft is :26207.35038490191

# %%
def area_price():
    import pandas as pd
    df = pd.read_csv(r"areaprice.csv")
    from sklearn.linear_model import LinearRegression
    reg = LinearRegression()
    reg.fit(df[['area']],df.price)
    
    start=int(input("Enter start limit :"))
    last=int(input("Enter last limit :"))
    for area in range(start,last+1,100):
        p = reg.predict([[area]])
        print(f"predicted price of area {area}sqft is :{p[0]}")
area_price()
# Out:
# Enter start limit :200
# Enter last limit :500
# predicted price of area 200sqft is :23057.611124906878
# predicted price of area 300sqft is :24107.524211571887
# predicted price of area 400sqft is :25157.4372982369
# predicted price of area 500sqft is :26207.35038490191

# %%
listA = []
listB = []
listC = []
listD = []
n = ""
while ('q'!= n):
    bank = str(input("Enter Bank Name :"))
    listA.append(bank) 
    amt = int(input("Enter Amount :"))
    listB.append(amt)
    rate = int(input("Enter Intrest_rate :"))
    listC.append(rate)
    year = int(input("Enter Time_durtion :"))
    listD.append(year)
    n = input("Quit for enter q else click enter")
# Out:
# Enter Bank Name :pnc
# Enter Amount :52000
# Enter Intrest_rate :12
# Enter Time_durtion :5
# Quit for enter q else click enter any key

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Bank_name':listA,
            'Amount':listB,
            'Rate':listC,
            'Year':listD
})
df

# %%
intr = df['Amount'] * (1+(df['Rate']/100))**df['Year']
df1 = df.assign(C_Intr =intr )

# %%
df1

# %%
print(123*(1+(2/100))**2)
print(4567*(1+(1/100))**1)
