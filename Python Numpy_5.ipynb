# %% [markdown]
# <h2 style="color:navy" > Numpy Operations </h2>

# %%
import numpy as np

# %%
x = np.array([1,8,9, 3, 0,5])

print(x.min())
print(x.max())
print()
print(x.argmin()) # return index of min value in array
print(x.argmax()) # return index of max value in array
# Out:
# 0
# 9
#
# 4
# 2

# %%
print(np.all([True, True, False]))

print(np.any([True, True, False]))
# Out:
# False
# True

# %%
x = np.array([1,2,0,-1])
y = np.array([0,0,0])
z = np.array([])

print(np.any(x!=0))
print(np.any(y!=0))
print(np.any(z!=0))
print()
print(np.all(x!=0))
print(np.all(y!=0))
print(np.all(z!=0))# Imp all returns True in case of empty
print()
print(np.all(x == 6))
print(np.all(y == 0))
# Out:
# True
# False
# False
#
# False
# False
# True
#
# False
# True

# %%
# Sum of axis
import numpy as np

x = np.array([(1,2,3),(4,5,6)])
print(x)
print()
print(x.sum(axis=0))
print(x.sum(axis=1))
# Out:
# [[1 2 3]
#  [4 5 6]]
#
# [5 7 9]
# [ 6 15]

# %%
# Find Square root
x = np.array([(4,9,16),(121,144,169)])
sqrt_x = np.sqrt(x)
sqrt_x
# Out:
# array([[ 2.,  3.,  4.],
#        [11., 12., 13.]])

# %% [markdown]
# ### Statistics:

# %%
import numpy as np
x = np.array([1, 2, 3, 5,5])

print(x.mean())
print(np.median(x))
# Out:
# 3.2
# 3.0

# %%
y = np.array([[1, 2, 3], [5, 6, 1]])
print(np.median(y, axis=-1)) # last axis
# Out:
# [2. 5.]

# %%
# Find std Deviaton
x = np.array([1,2,3,4,1])
y = np.array([(1,2,3),(4,5,6)])
std_x =np.std(x)
std_y = np.std(y)
print(std_x)
print(std_y)
# Out:
# 1.16619037896906
# 1.707825127659933

# %% [markdown]
# ###  Arithmetic Operations:

# %%
arr1 = np.array((1,2,3))  
  
print('First array:')  
print(arr1) 
  
print('\nSecond array:')  
arr2 = np.array((4,5,6))  
print(arr2) 
  
print('\nAdding the two arrays:')  
print(np.add(arr1, arr2)) 
  
print('\nSubtracting the two arrays:')  
print(np.subtract(arr1, arr2)) 
  
print('\nMultiplying the two arrays:') 
print(np.multiply(arr1, arr2)) 
  
print('\nDividing the two arrays:') 
print(np.divide(arr1, arr2))
# Out:
# First array:
# [1 2 3]
#
# Second array:
# [4 5 6]
#
# Adding the two arrays:
# [5 7 9]
#
# Subtracting the two arrays:
# [-3 -3 -3]
#
# Multiplying the two arrays:
# [ 4 10 18]
#
# Dividing the two arrays:
# [0.25 0.4  0.5 ]

# %%
arr1 = np.array(((1,2,3),(7,8,9)))  
  
print('First array:')  
print(arr1) 
  
print('\nSecond array:')  
arr2 = np.array((4,5,6))  
print(arr2) 
  
print('\nAdding the two arrays:')  
print(np.add(arr1, arr2)) 
  
print('\nSubtracting the two arrays:')  
print(np.subtract(arr1, arr2)) 
  
print('\nMultiplying the two arrays:') 
print(np.multiply(arr1, arr2)) 
  
print('\nDividing the two arrays:') 
print(np.divide(arr1, arr2))

# %%
import numpy as np  

arr = np.array([5, 10, 15])  
  
print('First array is:')  
print(arr) 
  
print('\nApplying power function:')  
print(np.power(arr, 2)) 
  
print('\nSecond array is:')  
arr1 = np.array([1, 2, 3])  
print(arr1) 
  
print('\nApplying power function again:')  
print(np.power(arr, arr1))
# Out:
# First array is:
# [ 5 10 15]
#
# Applying power function:
# [ 25 100 225]
#
# Second array is:
# [1 2 3]
#
# Applying power function again:
# [   5  100 3375]

# %%
10**2

# %%
15**3
# Out:
# 3375

# %% [markdown]
# ### numpy.mod()
#
# * This function returns the remainder of division of the corresponding elements in the input array. The function numpy.remainder() also produces the same result.

# %%
import numpy as np  
  
arr = np.array([5, 15, 20])  
arr1 = np.array([2, 5, 9])  
  
print('First array:')  
print(arr)  
  
print('\nSecond array:')  
print(arr1) 
  
print('\nApplying mod() function:')  
print(np.mod(arr, arr1)) 
  
print('\nApplying remainder() function:')  
print(np.remainder(arr, arr1))
# Out:
# First array:
# [ 5 15 20]
#
# Second array:
# [2 5 9]
#
# Applying mod() function:
# [1 0 2]
#
# Applying remainder() function:
# [1 0 2]

# %% [markdown]
# ### Numpy dot product
#
# ![dot.png](attachment:dot.png)

# %%
import numpy as geek 
  
vector_a = geek.array([[1, 4], [5, 6]]) 
vector_b = geek.array([[2, 4], [5, 2]]) 
  
product = geek.dot(vector_a, vector_b) 
print("Dot Product  : \n", product) 
  
product = geek.dot(vector_b, vector_a) 
print("\nDot Product  : \n", product)
# Out:
# Dot Product  :
#  [[22 12]
#  [40 32]]
#
# Dot Product  :
#  [[22 32]
#  [15 32]]

# %%
print(vector_a)
print(vector_b)
# Out:
# [[1 4]
#  [5 6]]
# [[2 4]
#  [5 2]]
